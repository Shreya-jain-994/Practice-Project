# %%
# Import necssary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score,roc_auc_score,plot_roc_curve,roc_curve,r2_score
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset and convert into dataframe
data = pd.read_excel('Flight_Ticket_Participant_Datasets_Data_Train.xlsx')
#Looking into first 5 rows
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# display Maximum rows
pd.set_option('display.max.rows',None)

# %%
# Checking columns name
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
# Checking shape of dataset
data.shape
# Out:
# (10683, 11)

# %%
# There are 10683  columns and 11 rows in dataset

# %%
#Checking the datatype of each attribute
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
# Identifing the type of Problem- Output: Price is contionus data so we use regression models

# %%
#removing duplicate values
data.drop_duplicates(inplace = True)

# %%
# After removing duplicates checking shape
data.shape
# Out:
# (10463, 11)

# %%
# there are 220 duplicates rows  remove in dataset

# %%
# Checking Null values of each attributes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10463 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10463 non-null  object
#  1   Date_of_Journey  10463 non-null  object
#  2   Source           10463 non-null  object
#  3   Destination      10463 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10463 non-null  object
#  6   Arrival_Time     10463 non-null  object
#  7   Duration         10463 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10463 non-null  object
#  10  Price            10463 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 980.9+ KB

# %%
# There is no null value present

# %%
# Checking missing values of each attributes
data.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# # we see that 2  attribute has missing values - Route & Total_Stops

# %%
data['Route'].unique()
# Out:
# array(['BLR → DEL', 'CCU → IXR → BBI → BLR', 'DEL → LKO → BOM → COK',
#        'CCU → NAG → BLR', 'BLR → NAG → DEL', 'CCU → BLR',
#        'BLR → BOM → DEL', 'DEL → BOM → COK', 'DEL → BLR → COK',
#        'MAA → CCU', 'CCU → BOM → BLR', 'DEL → AMD → BOM → COK',
#        'DEL → PNQ → COK', 'DEL → CCU → BOM → COK', 'BLR → COK → DEL',
#        'DEL → IDR → BOM → COK', 'DEL → LKO → COK',
#        'CCU → GAU → DEL → BLR', 'DEL → NAG → BOM → COK',
#        'CCU → MAA → BLR', 'DEL → HYD → COK', 'CCU → HYD → BLR',
#        'DEL → COK', 'CCU → DEL → BLR', 'BLR → BOM → AMD → DEL',
#        'BOM → DEL → HYD', 'DEL → MAA → COK', 'BOM → HYD',
#        'DEL → BHO → BOM → COK', 'DEL → JAI → BOM → COK',
#        'DEL → ATQ → BOM → COK', 'DEL → JDH → BOM → COK',
#        'CCU → BBI → BOM → BLR', 'BLR → MAA → DEL',
#        'DEL → GOI → BOM → COK', 'DEL → BDQ → BOM → COK',
#        'CCU → JAI → BOM → BLR', 'CCU → BBI → BLR', 'BLR → HYD → DEL',
#        'DEL → TRV → COK', 'CCU → IXR → DEL → BLR',
#        'DEL → IXU → BOM → COK', 'CCU → IXB → BLR',
#        'BLR → BOM → JDH → DEL', 'DEL → UDR → BOM → COK',
#        'DEL → HYD → MAA → COK', 'CCU → BOM → COK → BLR',
#        'BLR → CCU → DEL', 'CCU → BOM → GOI → BLR',
#        'DEL → RPR → NAG → BOM → COK', 'DEL → HYD → BOM → COK',
#        'CCU → DEL → AMD → BLR', 'CCU → PNQ → BLR',
#        'BLR → CCU → GAU → DEL', 'CCU → DEL → COK → BLR',
#        'BLR → PNQ → DEL', 'BOM → JDH → DEL → HYD',
#        'BLR → BOM → BHO → DEL', 'DEL → AMD → COK', 'BLR → LKO → DEL',
#        'CCU → GAU → BLR', 'BOM → GOI → HYD', 'CCU → BOM → AMD → BLR',
#        'CCU → BBI → IXR → DEL → BLR', 'DEL → DED → BOM → COK',
#        'DEL → MAA → BOM → COK', 'BLR → AMD → DEL', 'BLR → VGA → DEL',
#        'CCU → JAI → DEL → BLR', 'CCU → AMD → BLR',
#        'CCU → VNS → DEL → BLR', 'BLR → BOM → IDR → DEL',
#        'BLR → BBI → DEL', 'BLR → GOI → DEL', 'BOM → AMD → ISK → HYD',
#        'BOM → DED → DEL → HYD', 'DEL → IXC → BOM → COK',
#        'CCU → PAT → BLR', 'BLR → CCU → BBI → DEL',
#        'CCU → BBI → HYD → BLR', 'BLR → BOM → NAG → DEL',
#        'BLR → CCU → BBI → HYD → DEL', 'BLR → GAU → DEL',
#        'BOM → BHO → DEL → HYD', 'BOM → JLR → HYD',
#        'BLR → HYD → VGA → DEL', 'CCU → KNU → BLR',
#        'CCU → BOM → PNQ → BLR', 'DEL → BBI → COK',
#        'BLR → VGA → HYD → DEL', 'BOM → JDH → JAI → DEL → HYD',
#        'DEL → GWL → IDR → BOM → COK', 'CCU → RPR → HYD → BLR',
#        'CCU → VTZ → BLR', 'CCU → DEL → VGA → BLR',
#        'BLR → BOM → IDR → GWL → DEL', 'CCU → DEL → COK → TRV → BLR',
#        'BOM → COK → MAA → HYD', 'BOM → NDC → HYD', 'BLR → BDQ → DEL',
#        'CCU → BOM → TRV → BLR', 'CCU → BOM → HBX → BLR',
#        'BOM → BDQ → DEL → HYD', 'BOM → CCU → HYD',
#        'BLR → TRV → COK → DEL', 'BLR → IDR → DEL',
#        'CCU → IXZ → MAA → BLR', 'CCU → GAU → IMF → DEL → BLR',
#        'BOM → GOI → PNQ → HYD', 'BOM → BLR → CCU → BBI → HYD',
#        'BOM → MAA → HYD', 'BLR → BOM → UDR → DEL',
#        'BOM → UDR → DEL → HYD', 'BLR → VGA → VTZ → DEL',
#        'BLR → HBX → BOM → BHO → DEL', 'CCU → IXA → BLR',
#        'BOM → RPR → VTZ → HYD', 'BLR → HBX → BOM → AMD → DEL',
#        'BOM → IDR → DEL → HYD', 'BOM → BLR → HYD', 'BLR → STV → DEL',
#        'CCU → IXB → DEL → BLR', 'BOM → JAI → DEL → HYD',
#        'BOM → VNS → DEL → HYD', 'BLR → HBX → BOM → NAG → DEL', nan,
#        'BLR → BOM → IXC → DEL', 'BLR → CCU → BBI → HYD → VGA → DEL',
#        'BOM → BBI → HYD'], dtype=object)

# %%
data["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
# In these case we drop nan value
data.dropna(inplace= True)

# %%
#Looking for missing value
sns.heatmap(data.isna())
plt.show()

# %%
# Now there is null value in dataset

# %%
sns.distplot(data['Price'])
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.countplot(data['Airline'])
plt.show()

# %%
# Jet Airways has  largest number of  flight, then indigo and after indigo air india flightes

# %%
plt.figure(figsize = (40,7))
sns.boxplot(data['Date_of_Journey'], data['Price'])
plt.show()

# %%
data['Source'].value_counts()
# Out:
# Delhi       4345
# Kolkata     2860
# Banglore    2179
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
sns.countplot(data['Source'])
plt.show()

# %%
# we see that Maximum number of flight Source was Delhi, & than Kolkata  Destination.

# %%
data['Destination'].value_counts()
# Out:
# Cochin       4345
# Banglore     2860
# Delhi        1265
# New Delhi     914
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
sns.countplot(data['Destination'])
plt.show()

# %%
# Cochin  and banglore has highest destination.

# %%
data['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3475
# 2 stops     1318
# 3 stops       43
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
sns.countplot(data['Total_Stops'])
plt.show()

# %%
# Most of flight has 1 stop is 5625 and non stop flight has 3475

# %%
sns.countplot(data['Duration'])
plt.show()

# %%
plt.figure(figsize = (25,5), facecolor='white')
sns.countplot(data['Additional_Info'])
plt.show()

# %%
# There is no additional_ info

# %%
plt.figure(figsize = (30,5), facecolor='white')
sns.barplot(data['Airline'], data['Price'])
plt.xlabel('Airline', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.title('Airline vs Price')
plt.show()

# %%
# JetAirway flight are very expensive compare to other

# %%
plt.figure(figsize = (30,5), facecolor='white')
sns.barplot(data['Source'], data['Price'])
plt.xlabel('Source', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.title('Price vs Source')
plt.show()

# %%
# Highest price is delhi, Kolkata  and then banglore

# %%
plt.figure(figsize = (30,5), facecolor='white')
sns.stripplot(data['Destination'], data['Price'])
plt.xlabel('Destination', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.title('Destination vs Price')
plt.show()

# %%
# Destination price of Kolkata and delhi and  Hyderbad is low comapare tp other Destination

# %%
plt.figure(figsize = (30,5), facecolor='white')
plt.scatter(data['Total_Stops'], data['Price'])
plt.xlabel('Total_Stops', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.title('Total_Stops vs Price')
plt.show()

# %%
# Flight which have one stop & two stops has highest price,Flights which have four stops have the lowest prices,Flights which have zero and three stops have low prices.

# %%
data['Date'] = data['Date_of_Journey'].str.split('/').str[0]
data['Month'] = data['Date_of_Journey'].str.split('/').str[1]
data['Year'] = data['Date_of_Journey'].str.split('/').str[2]

# %%
plt.scatter(x=data['Date'],y=data['Price'])
plt.show()

# %%
# Flights have the highest prices on the first day of months  and lowest at 21 day of month

# %%
plt.scatter(x=data['Month'],y=data['Price'])
plt.show()

# %%
# Flights have the highest prices in the March, and may

# %%
sns.boxplot(x=data['Year'],y=data['Price'])
plt.show()

# %%
# Only show 2019 year

# %%
#Converting Route from string to numbers
data['Route1']=data['Route'].str.split('→').str[0]
data['Route2']=data['Route'].str.split('→').str[1]
data['Route3']=data['Route'].str.split('→').str[2]
data['Route4']=data['Route'].str.split('→').str[3]
data['Route5']=data['Route'].str.split('→').str[4]

# %%
data['Route1'].isna().sum()
# Out:
# 0

# %%
data['Route2'].isna().sum()
# Out:
# 0

# %%
data['Route3'].isna().sum()
# Out:
# 3475

# %%
data['Route3'].fillna(data['Route3'].mode()[0],inplace = True)

# %%
data['Route3'].isna().sum()
# Out:
# 0

# %%
data['Route4'].isna().sum()
# Out:
# 9100

# %%
data['Route5'].isna().sum()
# Out:
# 10418

# %%
# Route4 and Route5 columns have more than 50% null values. So, we will drop these columns.
data.drop(['Route4','Route5'],axis=1,inplace=True)

# %%
data['Dep_Hours']=data['Dep_Time'].str.split(':').str[0].astype('int')
data['Dep_Minutes']=data['Dep_Time'].str.split(':').str[0].astype('int')

# %%
sns.boxplot(x=data['Dep_Hours'],y=data['Price'])
plt.show()

# %%
#Flights which departed at 1 AM for departure have the lowest prices, 3 AM, 10 AM, 12 PM, 13 PM and 15 PM have also low prices,5 AM have the highest prices,9 AM, 16 PM, 18 PM, 20 PM and 22 PM have also high prices.

# %%
sns.boxplot(x=data['Dep_Minutes'],y=data['Price'])
plt.show()

# %%
data['Arrival_Time']=data['Arrival_Time'].str.split(' ').str[0]

# %%
data['Arrival_Hour']=data['Arrival_Time'].str.split(':').str[0]

# %%
data['Arrival_Hour'] =data['Arrival_Hour'].astype('int')

# %%
data['Arrival_Minute']=data['Arrival_Time'].str.split(':').str[1]

# %%
data['Arrival_Minute']=data['Arrival_Minute'].astype('int')

# %%
data['Duration_Hours']=data['Duration'].str.split('h').str[0]

# %%
data['Duration_Hours']=data['Duration_Hours'].replace('5m','0')

# %%
data['Duration_Hours']=data['Duration_Hours'].astype('int')

# %%
sns.boxplot(x=data['Duration_Hours'],y=data['Price'])
plt.show()

# %%
# Flight has highest 5 hours duration

# %%
data['Duration_Minutes']=data['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
data['Duration_Minutes']=data['Duration_Minutes'].fillna(data['Duration_Minutes'].mode()[0])

# %%
data['Duration_Minutes']=data['Duration_Minutes'].astype('int')

# %%
sns.stripplot(x=data['Duration_Minutes'],y=data['Price'])
plt.show()

# %%
# As we have split 'Date_of_Journey','Route','Dep_Time' , 'Arrival_Time','Duration' columns. So, we well drop these columns.
data.drop(['Date_of_Journey','Route','Dep_Time', 'Arrival_Time','Duration'],axis=1,inplace=True)

# %%
# we separate object datatypes
object_columns = []
for i in data.columns:
    if data[i].dtypes=='object':
        object_columns.append(i)

# %%
# Now we conver object datypes into numerical datatype
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for j in object_columns:
    data[j] = le.fit_transform(data[j])

# %%
# Checking  Statistics Summary
data.describe()
# Out:
#             Airline        Source   Destination   Total_Stops  \
# count  10462.000000  10462.000000  10462.000000  10462.000000
# mean       3.981074      1.953642      1.439495      1.463105
# std        2.364627      1.186327      1.481015      1.821371
# min        0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      2.000000      0.000000      0.000000
# 50%        4.000000      2.000000      1.000000      0.000000
# 75%        4.000000      3.000000      2.000000      4.000000
# max       11.000000      4.000000      5.000000      4.000000
#
#        Additional_Info         Price          Date         Month     Year  \
# count     10462.000000  10462.000000  10462.000000  10462.000000  10462.0
# mean          7.396483   9026.790289      8.417320      1.701491      0.0
# std           1.212030   4624.849541      3.223474      1.163802      0.0
# min           0.000000   1759.000000      0.000000      0.000000      0.0
# 25%           8.000000   5224.000000      6.000000      0.000000      0.0
# 50%           8.000000   8266.000000      9.000000      2.000000      0.0
# 75%           8.000000  12344.750000     11.000000      3.000000      0.0
# max           9.000000  79512.000000     13.000000      3.000000      0.0
#
#              Route1        Route2        Route3     Dep_Hours   Dep_Minutes  \
# count  10462.000000  10462.000000  10462.000000  10462.000000  10462.000000
# mean       2.004970     11.784649      5.738960     12.478494     12.478494
# std        1.208648      7.833805      2.659753      5.727227      5.727227
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      7.000000      4.000000      8.000000      8.000000
# 50%        2.000000      7.000000      6.000000     11.000000     11.000000
# 75%        3.000000     14.000000      6.000000     18.000000     18.000000
# max        4.000000     44.000000     28.000000     23.000000     23.000000
#
#        Arrival_Hour  Arrival_Minute  Duration_Hours  Duration_Minutes
# count  10462.000000    10462.000000    10462.000000      10462.000000
# mean      13.387689       24.719939       10.026190         31.094437
# std        6.855547       16.570450        8.378023         14.155880
# min        0.000000        0.000000        0.000000          5.000000
# 25%        8.000000       10.000000        2.000000         20.000000
# 50%       14.000000       25.000000        8.000000         30.000000
# 75%       19.000000       35.000000       15.000000         45.000000
# max       23.000000       55.000000       47.000000         55.000000

# %%
#Checking Correlation
data.corr()
# Out:
#                    Airline    Source  Destination  Total_Stops  \
# Airline           1.000000 -0.012172     0.015942     0.034396
# Source           -0.012172  1.000000    -0.589992    -0.222859
# Destination       0.015942 -0.589992     1.000000     0.334097
# Total_Stops       0.034396 -0.222859     0.334097     1.000000
# Additional_Info  -0.058220 -0.021587     0.024922     0.164639
# Price            -0.036491  0.013796    -0.065875    -0.571991
# Date              0.025755  0.186842    -0.291621    -0.034467
# Month             0.026083  0.181072    -0.362186    -0.021409
# Year                   NaN       NaN          NaN          NaN
# Route1            0.039836  0.437508    -0.479180    -0.442580
# Route2           -0.063741  0.036686     0.084999     0.040194
# Route3           -0.089960 -0.224964     0.344581     0.113399
# Dep_Hours        -0.032267  0.060218    -0.074056     0.040310
# Dep_Minutes      -0.032267  0.060218    -0.074056     0.040310
# Arrival_Hour     -0.005438  0.028257    -0.044605    -0.099351
# Arrival_Minute   -0.073045  0.021392     0.016351     0.176743
# Duration_Hours   -0.151962  0.167051    -0.255273    -0.613582
# Duration_Minutes -0.028782 -0.237278     0.059539     0.186927
#
#                   Additional_Info     Price      Date     Month  Year  \
# Airline                 -0.058220 -0.036491  0.025755  0.026083   NaN
# Source                  -0.021587  0.013796  0.186842  0.181072   NaN
# Destination              0.024922 -0.065875 -0.291621 -0.362186   NaN
# Total_Stops              0.164639 -0.571991 -0.034467 -0.021409   NaN
# Additional_Info          1.000000 -0.068779  0.018741 -0.049186   NaN
# Price                   -0.068779  1.000000 -0.073780 -0.113396   NaN
# Date                     0.018741 -0.073780  1.000000  0.115311   NaN
# Month                   -0.049186 -0.113396  0.115311  1.000000   NaN
# Year                          NaN       NaN       NaN       NaN   NaN
# Route1                   0.020189  0.173508  0.274491  0.224097   NaN
# Route2                   0.096554 -0.098391  0.004873  0.037930   NaN
# Route3                   0.099777 -0.016138 -0.061170 -0.205867   NaN
# Dep_Hours               -0.059406  0.005155 -0.006545  0.040406   NaN
# Dep_Minutes             -0.059406  0.005155 -0.006545  0.040406   NaN
# Arrival_Hour             0.021293  0.031023 -0.008057  0.001423   NaN
# Arrival_Minute           0.044321 -0.086163 -0.025292 -0.099261   NaN
# Duration_Hours          -0.171039  0.504200  0.018603  0.006410   NaN
# Duration_Minutes         0.048307 -0.120346 -0.038553 -0.018406   NaN
#
#                     Route1    Route2    Route3  Dep_Hours  Dep_Minutes  \
# Airline           0.039836 -0.063741 -0.089960  -0.032267    -0.032267
# Source            0.437508  0.036686 -0.224964   0.060218     0.060218
# Destination      -0.479180  0.084999  0.344581  -0.074056    -0.074056
# Total_Stops      -0.442580  0.040194  0.113399   0.040310     0.040310
# Additional_Info   0.020189  0.096554  0.099777  -0.059406    -0.059406
# Price             0.173508 -0.098391 -0.016138   0.005155     0.005155
# Date              0.274491  0.004873 -0.061170  -0.006545    -0.006545
# Month             0.224097  0.037930 -0.205867   0.040406     0.040406
# Year                   NaN       NaN       NaN        NaN          NaN
# Route1            1.000000 -0.098768 -0.119493  -0.047462    -0.047462
# Route2           -0.098768  1.000000  0.071139  -0.106472    -0.106472
# Route3           -0.119493  0.071139  1.000000  -0.130090    -0.130090
# Dep_Hours        -0.047462 -0.106472 -0.130090   1.000000     1.000000
# Dep_Minutes      -0.047462 -0.106472 -0.130090   1.000000     1.000000
# Arrival_Hour      0.021514  0.000592 -0.007152  -0.003827    -0.003827
# Arrival_Minute   -0.172785  0.043878  0.004392   0.072989     0.072989
# Duration_Hours    0.283602  0.020765 -0.028487  -0.000648    -0.000648
# Duration_Minutes -0.300543  0.026542 -0.008787  -0.022749    -0.022749
#
#                   Arrival_Hour  Arrival_Minute  Duration_Hours  \
# Airline              -0.005438       -0.073045       -0.151962
# Source                0.028257        0.021392        0.167051
# Destination          -0.044605        0.016351       -0.255273
# Total_Stops          -0.099351        0.176743       -0.613582
# Additional_Info       0.021293        0.044321       -0.171039
# Price                 0.031023       -0.086163        0.504200
# Date                 -0.008057       -0.025292        0.018603
# Month                 0.001423       -0.099261        0.006410
# Year                       NaN             NaN             NaN
# Route1                0.021514       -0.172785        0.283602
# Route2                0.000592        0.043878        0.020765
# Route3               -0.007152        0.004392       -0.028487
# Dep_Hours            -0.003827        0.072989       -0.000648
# Dep_Minutes          -0.003827        0.072989       -0.000648
# Arrival_Hour          1.000000       -0.152036        0.065586
# Arrival_Minute       -0.152036        1.000000       -0.075942
# Duration_Hours        0.065586       -0.075942        1.000000
# Duration_Minutes     -0.072305        0.097850       -0.133969
#
#                   Duration_Minutes
# Airline                  -0.028782
# Source                   -0.237278
# Destination               0.059539
# Total_Stops               0.186927
# Additional_Info           0.048307
# Price                    -0.120346
# Date                     -0.038553
# Month                    -0.018406
# Year                           NaN
# Route1                   -0.300543
# Route2                    0.026542
# Route3                   -0.008787
# Dep_Hours                -0.022749
# Dep_Minutes              -0.022749
# Arrival_Hour             -0.072305
# Arrival_Minute            0.097850
# Duration_Hours           -0.133969
# Duration_Minutes          1.000000

# %%
# we can understanding properly as we use heatmap to find correleation

# %%
#Checking of correlation of features with each other
plt.figure(figsize=(25,20))
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)
plt.show()

# %%
# Source as positive raltionship with route1
# Price as positive reltionship with  Duaration, & route 1

# %%
#Correlation with Price with respect to attributes
data.corrwith(data.Price).plot.bar(
        figsize = (20, 8), title = "Correlation with Price Graph", fontsize = 12,
        rot = 30, grid = True)
plt.show()

# %%
# Price as positive corelationship with  Duaration, & route 1
# Price as  highly negative corelationship with Total_stops

# %%
#Drawing Pairplot
sns.pairplot(data)
plt.show()

# %%
#

# %%
# Chekcing Outlier and skeweness
# let's see how data is distributed for every column
plt.figure(figsize=(15,13), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=18 :     # as there are 18 columns in the data
        ax = plt.subplot(3,6,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.show()

# %%
data.skew()
# Out:
# Airline             0.723567
# Source             -0.419669
# Destination         1.225081
# Total_Stops         0.617105
# Additional_Info    -1.796501
# Price               1.857490
# Date               -0.304317
# Month              -0.377535
# Year                0.000000
# Route1             -0.593710
# Route2              1.491868
# Route3              4.061959
# Dep_Hours           0.108306
# Dep_Minutes         0.108306
# Arrival_Hour       -0.378978
# Arrival_Minute      0.110802
# Duration_Hours      0.892650
# Duration_Minutes   -0.004311
# dtype: float64

# %%
# Because of all object dtype we ignore skewness

# %%
# Spliting dataset into features and label 
x = data.drop(["Price"], axis=1)
y = data["Price"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaler = scaler.fit_transform(x)

# %%
# To find the best random state using Linear Regressor model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

maxAccu=0
maxRS=0

maxR2_Score=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(X_scaler,y,test_size=.30,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    predrf = LR.predict(x_test)
    score = r2_score(y_test, predrf)
    if score>maxR2_Score:
        maxR2_Score=score
        maxRS=i
print("Best accuracy is",maxR2_Score," on Random_state ",maxRS)
# Out:
# Best accuracy is 0.45681935550922204  on Random_state  123

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scaler,y,test_size=.30,random_state=maxRS)

# %%
model=[LinearRegression(),RandomForestRegressor(),DecisionTreeRegressor(),KNeighborsRegressor(),GradientBoostingRegressor(),Ridge(),SVR(),AdaBoostRegressor()]

# %%
for m in model:
    print("*******************************************************************************")
    
    print('accuracy score of ->', m)
    
    m.fit(x_train,y_train)
    
    pred = m.predict(x_test)
    
    print("R2 Score:                ", r2_score(y_test,pred))
    
    print("Mean Absolute Error:     ", mean_absolute_error(y_test,pred))
    
    print("Mean Squared error:      ", mean_squared_error(y_test,pred))
    
    print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test,pred)))
    
    score=cross_val_score(m,x,y,cv=5)
    
    print(score)
    
    print("cross validation score:  ", abs(score.mean()))
    
    print("Difference between R2 score and cross validatio score is -> ",r2_score(y_test,pred)-abs(score.mean()))
    
    print("--------------------------------**********************--------------------------------------")
# Out:
# *******************************************************************************
# accuracy score of -> LinearRegression()
# R2 Score:                 0.45681935550922204
# Mean Absolute Error:      2412.5692246549897
# Mean Squared error:       10280991.974585121
# Root Mean Squared Error:  3206.3985988309564
# [0.41978737 0.41515499 0.41828732 0.39644881 0.39190795]
# cross validation score:   0.40831728978890974
# Difference between R2 score and cross validatio score is ->  0.04850206572031229
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> RandomForestRegressor()
# R2 Score:                 0.8982403123331191
# Mean Absolute Error:      666.5569330542029
# Mean Squared error:       1926045.3089602925
# Root Mean Squared Error:  1387.8203446268874
# [0.879111   0.88639086 0.87636326 0.88204675 0.8561703 ]
# cross validation score:   0.8760164319371068
# Difference between R2 score and cross validatio score is ->  0.022223880396012308
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> DecisionTreeRegressor()
# R2 Score:                 0.812588309636989
# Mean Absolute Error:      758.4286396941701
# Mean Squared error:       3547214.180232558
# Root Mean Squared Error:  1883.4049432431036
# [0.78301462 0.8485802  0.8121916  0.82012044 0.82087324]
# cross validation score:   0.8169560198751377
# Difference between R2 score and cross validatio score is ->  -0.004367710238148637
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> KNeighborsRegressor()
# R2 Score:                 0.7795268969211665
# Mean Absolute Error:      1212.0632685568653
# Mean Squared error:       4172980.437273016
# Root Mean Squared Error:  2042.7874185223034
# [0.65503614 0.64984841 0.65892559 0.68302009 0.64988799]
# cross validation score:   0.659343646041098
# Difference between R2 score and cross validatio score is ->  0.12018325088006854
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> GradientBoostingRegressor()
# R2 Score:                 0.8248183568570501
# Mean Absolute Error:      1238.6124486298881
# Mean Squared error:       3315731.3050720836
# Root Mean Squared Error:  1820.9149637124967
# [0.79626869 0.81059356 0.82837567 0.81231777 0.82945605]
# cross validation score:   0.8154023468637555
# Difference between R2 score and cross validatio score is ->  0.009416009993294616
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> Ridge()
# R2 Score:                 0.4568192792956891
# Mean Absolute Error:      2412.5784745499177
# Mean Squared error:       10280993.417108392
# Root Mean Squared Error:  3206.3988237754193
# [0.41978629 0.41515456 0.41828716 0.39644987 0.39190944]
# cross validation score:   0.40831746430974014
# Difference between R2 score and cross validatio score is ->  0.048501814985948966
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> SVR()
# R2 Score:                 0.027570274924688443
# Mean Absolute Error:      3405.7269719504234
# Mean Squared error:       18405556.789895948
# Root Mean Squared Error:  4290.169785672351
# [ 0.00903875 -0.00248746  0.01827467  0.02820993  0.01791125]
# cross validation score:   0.014189429017708944
# Difference between R2 score and cross validatio score is ->  0.013380845906979499
# --------------------------------**********************--------------------------------------
# *******************************************************************************
# accuracy score of -> AdaBoostRegressor()
# R2 Score:                 -0.14214527343208538
# Mean Absolute Error:      3921.222181070228
# Mean Squared error:       21617829.186409753
# Root Mean Squared Error:  4649.497734853707
# [-0.06981958 -0.38572331 -0.06602113  0.0568511   0.3559997 ]
# cross validation score:   0.0217426430410937
# Difference between R2 score and cross validatio score is ->  -0.16388791647317907
# --------------------------------**********************--------------------------------------

# %%
# we that GradientBoostingRegressor give best accuracy  82% and least difference

# %%
params={'n_estimators':range(0,200),
        'learning_rate':[.001,0.01,.1],
        'max_depth':[1,2,4],
        'subsample':[.5,.75,1]}

# %%
gridsearch = GridSearchCV(GradientBoostingRegressor(), param_grid=params,cv = 3, n_jobs = -1)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [1, 2, 4], 'n_estimators': range(0, 200),
#                          'subsample': [0.5, 0.75, 1]})

# %%
print(gridsearch.best_params_)
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 198, 'subsample': 0.75}

# %%
gbr = gridsearch.best_estimator_

# %%
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=4, n_estimators=198, subsample=0.75)

# %%
print(gbr.score(x_test,y_test))
# Out:
# 0.8806683279641919

# %%
y_pred =gbr.predict(x_test)

# %%
accuracy = r2_score(y_test,y_pred)

# %%
print(accuracy)
# Out:
# 0.8806683279641919

# %%
#hyperparameter tuning give 88 % accuracy

# %%
#Saving the model
import joblib 
joblib.dump(gbr,"Flight_Ticket_Participant_Datasets_Train.pkl")
# Out:
# ['Flight_Ticket_Participant_Datasets_Train.pkl']

# %%
# Test Data Set

# %%
# Load dataset and convert into dataframe
test_data = pd.read_excel('Flight_Ticket_Participant_Datasets_Test_set.xlsx')
#Looking into first 5 rows
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
# display Maximum rows
pd.set_option('display.max.rows',None)

# %%
# Checking columns name
test_data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
# Checking shape of dataset
test_data.shape
# Out:
# (2671, 10)

# %%
# There are 10683  columns and 11 rows in dataset

# %%
# Identifing the type of Problem- Output: Price is contionus data so we use regression models

# %%
#removing duplicate values
test_data.drop_duplicates(inplace = True)

# %%
# After removing duplicates checking shape
test_data.shape
# Out:
# (2645, 10)

# %%
# there are 26 duplicates rows  remove in dataset

# %%
#Checking the datatype of each attribute
test_data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# dtype: object

# %%
# Checking Null values of each attributes
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2645 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2645 non-null   object
#  1   Date_of_Journey  2645 non-null   object
#  2   Source           2645 non-null   object
#  3   Destination      2645 non-null   object
#  4   Route            2645 non-null   object
#  5   Dep_Time         2645 non-null   object
#  6   Arrival_Time     2645 non-null   object
#  7   Duration         2645 non-null   object
#  8   Total_Stops      2645 non-null   object
#  9   Additional_Info  2645 non-null   object
# dtypes: object(10)
# memory usage: 227.3+ KB

# %%
# There is no null value present

# %%
# Checking missing values of each attributes
test_data.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
#Looking for null values if any, in heatmap
sns.heatmap(test_data.isna())
plt.show()

# %%
# Now there is nonull value in dataset

# %%
test_data['Date']=test_data['Date_of_Journey'].str.split('/').str[0]
test_data['Month']=test_data['Date_of_Journey'].str.split('/').str[1]
test_data['Year']=test_data['Date_of_Journey'].str.split('/').str[2]

# %%
test_data['Route'].unique()
# Out:
# array(['DEL → BOM → COK', 'CCU → MAA → BLR', 'BLR → DEL',
#        'BLR → TRV → DEL', 'CCU → HYD → BLR', 'CCU → BLR',
#        'CCU → BOM → BLR', 'DEL → MAA → BOM → COK', 'DEL → HYD → COK',
#        'BLR → BOM → DEL', 'CCU → DEL → BLR', 'DEL → JAI → BOM → COK',
#        'DEL → BHO → BOM → COK', 'BOM → HYD', 'CCU → PNQ → BLR',
#        'MAA → CCU', 'CCU → BOM → COK → BLR', 'DEL → BLR → COK',
#        'DEL → HYD → MAA → COK', 'DEL → MAA → COK',
#        'CCU → IXR → BBI → BOM → BLR', 'CCU → DEL → AMD → BLR',
#        'DEL → COK', 'CCU → JAI → BOM → BLR', 'DEL → LKO → COK',
#        'CCU → IXB → BLR', 'DEL → CCU → BOM → COK',
#        'CCU → GAU → DEL → BLR', 'BLR → COK → DEL',
#        'BLR → BOM → NAG → DEL', 'CCU → BBI → BOM → BLR',
#        'BLR → AMD → DEL', 'BOM → DEL → HYD', 'DEL → GOI → BOM → COK',
#        'DEL → IXU → BOM → COK', 'DEL → HYD → BOM → COK',
#        'CCU → DEL → COK → BLR', 'BLR → GOI → DEL',
#        'BLR → BOM → BHO → DEL', 'DEL → IDR → BOM → COK',
#        'DEL → AMD → BOM → COK', 'DEL → RPR → NAG → BOM → COK',
#        'DEL → NAG → BOM → COK', 'CCU → PAT → BLR',
#        'BLR → HYD → VGA → DEL', 'BLR → BOM → IXC → DEL',
#        'BLR → BOM → IDR → DEL', 'CCU → VNS → DEL → BLR',
#        'CCU → BBI → BLR', 'BLR → MAA → DEL', 'CCU → IXR → DEL → BLR',
#        'CCU → BOM → GOI → BLR', 'DEL → ATQ → BOM → COK',
#        'BLR → VGA → DEL', 'DEL → BDQ → BOM → COK', 'BLR → HYD → DEL',
#        'BLR → BOM → AMD → DEL', 'DEL → DED → BOM → COK',
#        'DEL → AMD → COK', 'CCU → BOM → HBX → BLR', 'BLR → STV → DEL',
#        'CCU → KNU → BLR', 'DEL → TRV → COK', 'BLR → CCU → GAU → DEL',
#        'DEL → UDR → BOM → COK', 'BOM → BLR → HYD',
#        'CCU → BOM → AMD → BLR', 'DEL → JDH → BOM → COK',
#        'DEL → PNQ → COK', 'DEL → GWL → IDR → BOM → COK',
#        'BLR → BOM → IDR → GWL → DEL', 'BLR → BDQ → DEL',
#        'BOM → JDH → DEL → HYD', 'CCU → GAU → BLR',
#        'BLR → BOM → UDR → DEL', 'BLR → BBI → DEL',
#        'BOM → VGA → TIR → HYD', 'CCU → DEL → VGA → BLR',
#        'DEL → LKO → BOM → COK', 'CCU → JAI → DEL → BLR',
#        'CCU → NAG → BLR', 'BOM → JAI → DEL → HYD', 'BLR → CCU → DEL',
#        'BLR → VGA → VTZ → DEL', 'CCU → BOM → TRV → BLR',
#        'BOM → GOI → HYD', 'BOM → IXC → DEL → HYD',
#        'CCU → DEL → COK → TRV → BLR', 'BLR → GAU → DEL',
#        'BLR → BOM → JDH → DEL', 'DEL → IXC → BOM → COK',
#        'CCU → BBI → HYD → BLR', 'BLR → VGA → HYD → DEL',
#        'BLR → NAG → DEL', 'CCU → AMD → BLR', 'BOM → AMD → ISK → HYD',
#        'BLR → CCU → BBI → HYD → VGA → DEL', 'CCU → BBI → IXR → DEL → BLR',
#        'CCU → IXR → BBI → BLR', 'BOM → GOI → PNQ → HYD'], dtype=object)

# %%
#Converting Route from string to numbers
test_data['Route1']=test_data['Route'].str.split('→').str[0]
test_data['Route2']=test_data['Route'].str.split('→').str[1]
test_data['Route3']=test_data['Route'].str.split('→').str[2]
test_data['Route4']=test_data['Route'].str.split('→').str[3]
test_data['Route5']=test_data['Route'].str.split('→').str[4]

# %%
test_data['Route1'].isna().sum()
# Out:
# 0

# %%
test_data['Route2'].isna().sum()
# Out:
# 0

# %%
test_data['Route3'].isna().sum()
# Out:
# 846

# %%
test_data['Route3']=test_data['Route3'].fillna(test_data['Route3'].mode()[0])

# %%
test_data['Route4'].isna().sum()
# Out:
# 2273

# %%
test_data['Route5'].isna().sum()
# Out:
# 2633

# %%
# Route4 and Route5 columns have more than 50% null values. So, we will drop these columns.
test_data.drop(['Route4','Route5'],axis=1,inplace=True)

# %%
test_data['Dep_hours']=test_data['Dep_Time'].str.split(':').str[0]
test_data['Dep_Minutes']=test_data['Dep_Time'].str.split(':').str[1]

# %%
test_data['Dep_hours']=test_data['Dep_hours'].astype('int')
test_data['Dep_Minutes']=test_data['Dep_Minutes'].astype('int')

# %%
test_data['Arrival_Time']=test_data['Arrival_Time'].str.split(' ').str[0]

# %%
test_data['Arrival_Hours'] =test_data['Arrival_Time'].str.split(':').str[0].astype('int')
test_data['Arrival_Minutes'] =test_data['Arrival_Time'].str.split(':').str[1].astype('int')

# %%
test_data['Duration_Hours']=test_data['Duration'].str.split('h').str[0]

# %%
test_data['Duration_Hours']=test_data['Duration_Hours'].replace('5m','0')

# %%
test_data['Duration_Hours']=test_data['Duration_Hours'].astype('int')

# %%
test_data['Duration_Minutes']=test_data['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
test_data['Duration_Minutes']=test_data['Duration_Minutes'].fillna(test_data['Duration_Minutes'].mode()[0])

# %%
test_data['Duration_Minutes']=test_data['Duration_Minutes'].astype('int')

# %%
# As we have split 'Date_of_Journey','Route','Dep_Time' , 'Arrival_Time','Duration' columns. So, we well drop these columns.
test_data.drop(['Date_of_Journey','Route','Dep_Time', 'Arrival_Time','Duration'],axis=1,inplace=True)

# %%
# Now we Separate string and interger datatype
object_dtypes=[]
for i in test_data.columns:
    if test_data[i].dtypes=='object':
        object_dtypes.append(i)

# %%
# Now we convert object dtypes into numerica dtypes
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for j in object_dtypes:
    test_data[j]= le.fit_transform(test_data[j])

# %%
test_data.shape
# Out:
# (2645, 17)

# %%
test_data.describe()
# Out:
#            Airline       Source  Destination  Total_Stops  Additional_Info  \
# count  2645.000000  2645.000000  2645.000000  2645.000000      2645.000000
# mean      3.979962     1.963705     1.430624     1.424953         4.634026
# std       2.299275     1.186554     1.465761     1.801239         0.761135
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%       3.000000     2.000000     0.000000     0.000000         5.000000
# 50%       4.000000     2.000000     1.000000     0.000000         5.000000
# 75%       6.000000     3.000000     2.000000     4.000000         5.000000
# max      10.000000     4.000000     5.000000     4.000000         5.000000
#
#               Date        Month    Year       Route1       Route2  \
# count  2645.000000  2645.000000  2645.0  2645.000000  2645.000000
# mean      8.413611     1.715690     0.0     1.996597    11.401890
# std       3.271126     1.170134     0.0     1.200884     6.903643
# min       0.000000     0.000000     0.0     0.000000     0.000000
# 25%       6.000000     0.000000     0.0     1.000000     7.000000
# 50%       9.000000     2.000000     0.0     2.000000     7.000000
# 75%      11.000000     3.000000     0.0     3.000000    14.000000
# max      13.000000     3.000000     0.0     4.000000    38.000000
#
#             Route3    Dep_hours  Dep_Minutes  Arrival_Hours  Arrival_Minutes  \
# count  2645.000000  2645.000000  2645.000000    2645.000000      2645.000000
# mean      4.967486    12.615879    24.896030      13.597353        24.559546
# std       2.250164     5.679266    19.088499       7.025676        16.794025
# min       0.000000     0.000000     0.000000       0.000000         0.000000
# 25%       4.000000     8.000000     5.000000       8.000000        10.000000
# 50%       5.000000    12.000000    25.000000      15.000000        25.000000
# 75%       5.000000    18.000000    45.000000      19.000000        35.000000
# max      26.000000    23.000000    55.000000      23.000000        55.000000
#
#        Duration_Hours  Duration_Minutes
# count     2645.000000       2645.000000
# mean        10.122117         31.170132
# std          8.370658         13.971327
# min          0.000000          5.000000
# 25%          2.000000         20.000000
# 50%          8.000000         30.000000
# 75%         15.000000         45.000000
# max         40.000000         55.000000

# %%
#Checking Correlation
test_data.corr()
# Out:
#                    Airline    Source  Destination  Total_Stops  \
# Airline           1.000000 -0.032706     0.036453     0.040503
# Source           -0.032706  1.000000    -0.575119    -0.211329
# Destination       0.036453 -0.575119     1.000000     0.329479
# Total_Stops       0.040503 -0.211329     0.329479     1.000000
# Additional_Info  -0.083506 -0.024345     0.024695     0.136930
# Date              0.014981  0.167964    -0.281380    -0.037160
# Month             0.048208  0.166904    -0.348673    -0.006718
# Year                   NaN       NaN          NaN          NaN
# Route1            0.028193  0.445305    -0.519151    -0.478596
# Route2           -0.081124  0.035579     0.097188     0.083498
# Route3           -0.111242 -0.186437     0.325446     0.059026
# Dep_hours         0.006072  0.058995    -0.053725     0.069831
# Dep_Minutes      -0.048520 -0.062953     0.151377     0.050401
# Arrival_Hours    -0.017638  0.007048    -0.012942    -0.100582
# Arrival_Minutes  -0.096854 -0.004978     0.031984     0.194047
# Duration_Hours   -0.177991  0.154173    -0.247350    -0.596193
# Duration_Minutes -0.046188 -0.247485     0.076225     0.189437
#
#                   Additional_Info      Date     Month  Year    Route1  \
# Airline                 -0.083506  0.014981  0.048208   NaN  0.028193
# Source                  -0.024345  0.167964  0.166904   NaN  0.445305
# Destination              0.024695 -0.281380 -0.348673   NaN -0.519151
# Total_Stops              0.136930 -0.037160 -0.006718   NaN -0.478596
# Additional_Info          1.000000  0.030894 -0.011131   NaN  0.027602
# Date                     0.030894  1.000000  0.092095   NaN  0.247319
# Month                   -0.011131  0.092095  1.000000   NaN  0.223517
# Year                          NaN       NaN       NaN   NaN       NaN
# Route1                   0.027602  0.247319  0.223517   NaN  1.000000
# Route2                   0.103866  0.019483  0.024871   NaN -0.111788
# Route3                   0.085578 -0.034552 -0.216968   NaN -0.130629
# Dep_hours               -0.076193 -0.016018  0.018846   NaN -0.084706
# Dep_Minutes              0.009225 -0.035684 -0.108170   NaN -0.060485
# Arrival_Hours            0.006453 -0.008665  0.004518   NaN  0.010417
# Arrival_Minutes          0.034430 -0.002397 -0.144564   NaN -0.211895
# Duration_Hours          -0.143172  0.013487 -0.021283   NaN  0.303149
# Duration_Minutes         0.029438 -0.016304 -0.025912   NaN -0.302845
#
#                     Route2    Route3  Dep_hours  Dep_Minutes  Arrival_Hours  \
# Airline          -0.081124 -0.111242   0.006072    -0.048520      -0.017638
# Source            0.035579 -0.186437   0.058995    -0.062953       0.007048
# Destination       0.097188  0.325446  -0.053725     0.151377      -0.012942
# Total_Stops       0.083498  0.059026   0.069831     0.050401      -0.100582
# Additional_Info   0.103866  0.085578  -0.076193     0.009225       0.006453
# Date              0.019483 -0.034552  -0.016018    -0.035684      -0.008665
# Month             0.024871 -0.216968   0.018846    -0.108170       0.004518
# Year                   NaN       NaN        NaN          NaN            NaN
# Route1           -0.111788 -0.130629  -0.084706    -0.060485       0.010417
# Route2            1.000000  0.090049  -0.141694     0.087265       0.023877
# Route3            0.090049  1.000000  -0.106576     0.065918      -0.018939
# Dep_hours        -0.141694 -0.106576   1.000000    -0.032762      -0.006750
# Dep_Minutes       0.087265  0.065918  -0.032762     1.000000       0.047123
# Arrival_Hours     0.023877 -0.018939  -0.006750     0.047123       1.000000
# Arrival_Minutes   0.068760  0.011331   0.064686    -0.022736      -0.137529
# Duration_Hours   -0.007460  0.039648  -0.015497     0.023253       0.057630
# Duration_Minutes  0.036217  0.031347  -0.028843     0.023998      -0.081142
#
#                   Arrival_Minutes  Duration_Hours  Duration_Minutes
# Airline                 -0.096854       -0.177991         -0.046188
# Source                  -0.004978        0.154173         -0.247485
# Destination              0.031984       -0.247350          0.076225
# Total_Stops              0.194047       -0.596193          0.189437
# Additional_Info          0.034430       -0.143172          0.029438
# Date                    -0.002397        0.013487         -0.016304
# Month                   -0.144564       -0.021283         -0.025912
# Year                          NaN             NaN               NaN
# Route1                  -0.211895        0.303149         -0.302845
# Route2                   0.068760       -0.007460          0.036217
# Route3                   0.011331        0.039648          0.031347
# Dep_hours                0.064686       -0.015497         -0.028843
# Dep_Minutes             -0.022736        0.023253          0.023998
# Arrival_Hours           -0.137529        0.057630         -0.081142
# Arrival_Minutes          1.000000       -0.078689          0.120795
# Duration_Hours          -0.078689        1.000000         -0.102059
# Duration_Minutes         0.120795       -0.102059          1.000000

# %%
# we can understanding properly as we use heatmap to find correleation

# %%
#Checking of correlation of features with each other
plt.figure(figsize=(25,20))
sns.heatmap(test_data.corr(),cmap='YlOrRd_r',annot=True)
plt.show()

# %%
# Source and route 1 has positive correlationship

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(15,13), facecolor='white')
plotnumber = 1

for column in test_data:
    if plotnumber<=18 :     # as there are 17 columns in the data
        ax = plt.subplot(3,6,plotnumber)
        sns.distplot(test_data[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.show()

# %%
# Checking Skwness
test_data.skew()
# Out:
# Airline             0.482621
# Source             -0.424718
# Destination         1.260252
# Total_Stops         0.666765
# Additional_Info    -1.717307
# Date               -0.265024
# Month              -0.400537
# Year                0.000000
# Route1             -0.616347
# Route2              1.196607
# Route3              4.806541
# Dep_hours           0.089146
# Dep_Minutes         0.129932
# Arrival_Hours      -0.447350
# Arrival_Minutes     0.113229
# Duration_Hours      0.901931
# Duration_Minutes   -0.004593
# dtype: float64

# %%
# Because of all object dtype we ignore skewness

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaler = scaler.fit_transform(test_data)

# %%
import joblib
Price= joblib.load("Flight_Ticket_Participant_Datasets_Train.pkl")
Price_prediction = Price.predict(test_data)
Price_prediction
# Out:
# array([16373.05467831, 15903.21531159, 16785.74242345, ...,
#        16572.27452599, 14960.78878027, 16373.05467831])

# %%
Flight=pd.DataFrame({"Flight Price":Price_prediction})
Flight.head()
# Out:
#    Flight Price
# 0  16373.054678
# 1  15903.215312
# 2  16785.742423
# 3  13969.924973
# 4  15221.083941
